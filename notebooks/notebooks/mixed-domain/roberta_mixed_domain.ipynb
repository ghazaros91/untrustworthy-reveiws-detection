# %% [markdown]
# # Install Dependendcies

# %%
# !pip3 install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 5.0 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 36.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 37.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 2.5 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 17.1 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.6 transformers-4.16.2

# %%
# !nvidia-smi
# Out:
# Mon Feb 28 14:41:00 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %% [markdown]
# # Download the Dataset

# %%
# !gdown --id 1-n9aJG1zdWHL0UjuRWwa8Rro-ogoWxN7
# !unzip deception_dataset.zip && rm deception_dataset.zip && rm -r __MACOSX
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: deception_dataset/restaurant/deceptive_MTurk/85.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._85.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/153.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._153.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/147.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._147.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/146.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._146.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/152.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._152.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/84.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._84.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/90.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._90.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/185.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._185.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/191.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._191.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/47.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._47.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/1.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._1.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/53.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._53.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/34.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._34.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/20.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._20.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/135.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._135.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/121.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._121.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/109.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._109.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/108.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._108.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/120.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._120.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/134.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._134.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/21.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._21.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/35.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._35.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/23.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._23.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/37.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._37.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/122.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._122.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/136.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._136.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/137.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._137.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/123.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._123.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/36.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._36.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/22.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._22.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/26.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._26.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/32.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._32.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/127.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._127.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/133.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._133.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/132.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._132.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/126.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._126.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/33.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._33.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/27.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._27.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/31.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._31.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/25.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._25.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/19.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._19.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/118.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._118.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/130.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._130.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/124.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._124.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/125.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._125.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/131.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._131.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/119.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._119.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/18.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._18.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/24.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._24.txt
#   inflating: deception_dataset/restaurant/deceptive_MTurk/30.txt
#   inflating: __MACOSX/deception_dataset/restaurant/deceptive_MTurk/._30.txt
#    creating: deception_dataset/hotel/
#    creating: deception_dataset/hotel/positive/
#    creating: deception_dataset/hotel/positive/truthful/
#   inflating: deception_dataset/hotel/positive/truthful/t_hardrock_4.txt
#    creating: __MACOSX/deception_dataset/hotel/
#    creating: __MACOSX/deception_dataset/hotel/positive/
#    creating: __MACOSX/deception_dataset/hotel/positive/truthful/
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hardrock_4.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_knickerbocker_7.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_knickerbocker_7.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_james_17.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_james_17.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_talbott_17.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_talbott_17.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_palmer_12.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_palmer_12.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_swissotel_8.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_swissotel_8.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_conrad_1.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_conrad_1.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_sheraton_3.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_sheraton_3.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_omni_19.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_omni_19.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hilton_2.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hilton_2.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hardrock_16.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hardrock_16.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_allegro_12.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_allegro_12.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_omni_5.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_omni_5.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_amalfi_3.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_amalfi_3.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_ambassador_18.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_ambassador_18.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_knickerbocker_11.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_knickerbocker_11.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hyatt_10.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hyatt_10.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_talbott_4.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_talbott_4.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_talbott_5.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_talbott_5.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hyatt_11.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hyatt_11.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_knickerbocker_10.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_knickerbocker_10.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_james_1.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_james_1.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_ambassador_19.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_ambassador_19.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_amalfi_2.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_amalfi_2.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_omni_4.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_omni_4.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_allegro_13.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_allegro_13.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hardrock_17.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hardrock_17.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_omni_18.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_omni_18.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hilton_3.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hilton_3.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_sheraton_2.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_sheraton_2.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_swissotel_9.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_swissotel_9.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_talbott_16.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_talbott_16.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_palmer_13.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_palmer_13.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_james_16.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_james_16.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_knickerbocker_6.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_knickerbocker_6.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hardrock_5.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hardrock_5.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_knickerbocker_4.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_knickerbocker_4.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hardrock_7.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hardrock_7.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_palmer_11.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_palmer_11.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_talbott_14.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_talbott_14.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_james_14.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_james_14.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_conrad_2.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_conrad_2.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hilton_1.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hilton_1.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hardrock_15.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hardrock_15.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_allegro_11.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_allegro_11.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_omni_6.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_omni_6.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_james_3.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_james_3.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_knickerbocker_12.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_knickerbocker_12.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_intercontinental_8.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_intercontinental_8.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_talbott_7.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_talbott_7.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hyatt_13.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hyatt_13.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_hyatt_12.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t_hyatt_12.txt
#   inflating: deception_dataset/hotel/positive/truthful/t_intercontinental_9.txt
#   inflating: __MACOSX/deception_dataset/hotel/positive/truthful/._t
txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._126.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/33.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._33.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/27.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._27.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/244.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._244.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/250.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._250.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/278.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._278.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/287.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._287.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/293.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._293.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/285.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._285.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/291.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._291.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/246.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._246.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/252.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._252.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/31.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._31.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/25.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._25.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/19.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._19.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/118.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._118.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/130.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._130.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/124.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._124.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/332.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._332.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/326.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._326.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/327.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._327.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/333.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._333.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/125.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._125.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/131.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._131.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/119.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._119.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/18.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._18.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/24.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._24.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/30.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._30.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/253.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._253.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/247.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._247.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/290.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._290.txt
#   inflating: deception_dataset/doctor/deceptive_MTurk/284.txt
#   inflating: __MACOSX/deception_dataset/doctor/deceptive_MTurk/._284.txt

# %% [markdown]
# # Data Helpers

# %%
import numpy as np
import string
import os
import io
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

SEQUENCE_LEN = 200


def read_from_dir(in_fold_dir):
    reviews = []
    for filename in os.listdir(in_fold_dir):
        if filename.endswith(".txt"):
            # read from file containing the text review
            in_filepath = in_fold_dir + filename
            with io.open(in_filepath, 'r', encoding='windows-1252') as f:
                review = f.read()
                # if len(review) > SEQUENCE_LEN:
                #     review = review[:200]
                reviews.append(review)    

    # print("number of reviews: {}, name: {}".format(len(reviews), in_fold_dir)) 
    print(reviews[:2])         
    return reviews


def load_data():
    trustworthy_hotel_positive = read_from_dir('deception_dataset/hotel/positive/truthful/') 
    trustworthy_hotel_negative = read_from_dir('deception_dataset/hotel/negative/truthful/')
    trustworthy_restaurant = read_from_dir('deception_dataset/restaurant/truthful/')
    trustworthy_doctor = read_from_dir('deception_dataset/doctor/truthful/')[:200]

    untrustworthy_hotel_positive = read_from_dir('deception_dataset/hotel/positive/deceptive_turker/')
    untrustworthy_hotel_negative = read_from_dir('deception_dataset/hotel/negative/deceptive_turker/') 
    untrustworthy_hotel_expert_positive =  read_from_dir('deception_dataset/hotel/positive/deceptive_expert/')
    untrustworthy_hotel_expert_negative =  read_from_dir('deception_dataset/hotel/negative/deceptive_expert/')
    
    untrustworthy_restaurant = read_from_dir('deception_dataset/restaurant/deceptive_MTurk/')[:200]
    untrustworthy_doctor = read_from_dir('deception_dataset/doctor/deceptive_MTurk/')

    TRUSTWORTHY_REVIEWS_DICT = {}
    UNTRUSTWORTHY_REVIEWS_DICT = {}

    TRUSTWORTHY_REVIEWS_DICT["cross_domain"] = {
        "hotel":trustworthy_hotel_positive + trustworthy_hotel_negative,
        "restaurant":trustworthy_restaurant,
        "doctor":trustworthy_doctor
    }

    UNTRUSTWORTHY_REVIEWS_DICT["cross_domain"] = { 
        "hotel":untrustworthy_hotel_positive + untrustworthy_hotel_negative,
        "restaurant":untrustworthy_restaurant,
        "doctor":untrustworthy_doctor[:200]
    }

    TRUSTWORTHY_REVIEWS_DICT["mixed_domain"] = {
        "hotel":trustworthy_hotel_positive + trustworthy_hotel_negative,
        "restaurant":trustworthy_restaurant,
        "doctor":trustworthy_doctor
    }

    UNTRUSTWORTHY_REVIEWS_DICT["mixed_domain"] = { 
        "hotel":untrustworthy_hotel_positive + untrustworthy_hotel_expert_positive + untrustworthy_hotel_negative + untrustworthy_hotel_expert_negative,
        "restaurant":untrustworthy_restaurant,
        "doctor":untrustworthy_doctor
    }

    return TRUSTWORTHY_REVIEWS_DICT, UNTRUSTWORTHY_REVIEWS_DICT


quartino's several times for several different occasions for both business and leisure. Quartino's staff always knows how to tend to my needs perfectly--they are always very helpful and very knowledgeable about the daily specials and menu items. I loved the vintage decor throughout the restaurant and their great selection of wines. The thing I love most about this place is the option of choosing the shared menu where two people can eat a three meal course for a very reasonable price. They have valet parking which is always a plus and serve both individuals and large groups. You can book reservations directly on their website which is great because you can book on the go. I would definitely recommend the roasted calamari or salmon and my favorite pasta is the gnocchi. Chef Cotello is one amazing chef and his restaurant is by far one of the best in Chicago.\n"]
# ["Dr. Ali is my favorite doctor of all time. I had felt that I'd never get the care that I wanted or felt I deserved until I went to her. She listens very carefully and actually takes all of your symptoms and/or concerns into consideration instead of just focusing on one thing and not treating the other conditions or looking into other possibilities. It's refreshing to find a medical professional who actually cares. Finally, someone who truly knows what health CARE is. I highly recommend her to anyone looking for more personalized attention.\n", "Was always kind and understanding. We have been going to this doctor for many years and have always felt a warm environment. It's nice to be treated as a person and not just a number!\n"]

# %%
def get_reviews_from_dict(reviews_dict, keys = []):
    if not keys:
        raise Exception("Invalid key: key must be one of the following: \'hotel\', \'restaurant\', \'doctor\'")

    reviews = []
    for key in keys:
        if key in reviews_dict:
            reviews += reviews_dict[key]
        else:
            raise Exception("Invalid key: key must be one of the following: \'hotel\', \'restaurant\', \'doctor\'")
    return reviews

def get_reviews(review_type="", keys = [], data_name="cross_domain"):
    if not review_type:
        raise Exception("Invalid review_type: review_type must be either \'trustworthy\' or \'untrustworthy\'.")
    if not keys:
        raise Exception("Invalid key: key must be one of the follwowing: \'hotel\', \'restaurant\', \'doctor\'")

    if review_type=="trustworthy":
        return get_reviews_from_dict(reviews_dict=TRUSTWORTHY_REVIEWS_DICT[data_name], keys=keys)
    elif review_type=="untrustworthy":
        return get_reviews_from_dict(reviews_dict=UNTRUSTWORTHY_REVIEWS_DICT[data_name], keys=keys)
    else:
        raise Exception("Invalid review_type: review_type must be either \'trustworthy\' or \'untrustworthy\'.")


def get_data(keys=[], data_name="cross_domain"):
    if data_name != "cross_domain" and data_name != "mixed_domain":
        raise Exception("Invalid dataset name")

    trustworthy_reviews   = get_reviews(review_type="trustworthy", keys=keys, data_name=data_name)
    untrustworthy_reviews = get_reviews(review_type="untrustworthy", keys=keys, data_name=data_name)
    
    reviews = trustworthy_reviews + untrustworthy_reviews

    # generate labels
    labels_trustworthy   = [[1,0] for _ in range(len(trustworthy_reviews   ))]
    labels_untrustworthy = [[0,1] for _ in range(len(untrustworthy_reviews ))]
    labels = labels_trustworthy + labels_untrustworthy

    print("dataset_name: {}".format(data_name+"_"+keys[0]))
    print("trustworthy_reviews: {}".format(len(trustworthy_reviews)))
    print("untrustworthy_reviews: {}".format(len(untrustworthy_reviews)))
    print("reviews len: ", len(reviews))
    print("labels len: ", len(labels))
    print()
        
    return reviews, labels

# %%
import numpy as np
import os
import re
import itertools
import scipy.sparse as sp
from collections import Counter
import torch


SEQUENCE_LEN = 200


def build_vocab(sentences, vocab_size=50000):
    word_counts = Counter(itertools.chain(*sentences)) 
    vocabulary_inv = [x[0] for x in word_counts.most_common(vocab_size)]
    vocabulary = {x: i for i, x in enumerate(vocabulary_inv)}
    # append <UNK/> symbol to the vocabulary
    vocabulary['<UNK/>'] = len(vocabulary)
    vocabulary_inv.append('<UNK/>')
    return [vocabulary, vocabulary_inv]


def build_input_data(sentences, vocabulary):
    x = np.array([[vocabulary[word] if word in vocabulary else vocabulary['<UNK/>'] for word in sentence] for sentence in sentences])
    return x


def load_data(fold = 1, vocab_size=30001):
    # Load data
    trustworthy_reviews_for_training, trustworthy_reviews_for_testing, untrustworthy_reviews_for_training, untrustworthy_reviews_for_testing = data.load_data(fold=fold)
    train = trustworthy_reviews_for_training + untrustworthy_reviews_for_training
    test  = trustworthy_reviews_for_testing + untrustworthy_reviews_for_testing

    # generate labels
    train_labels1 = [[1,0] for _ in range(len(trustworthy_reviews_for_training   ))]
    train_labels0 = [[0,1] for _ in range(len(untrustworthy_reviews_for_training ))]
    test_labels1  = [[1,0] for _ in range(len(trustworthy_reviews_for_testing    ))]
    test_labels0  = [[0,1] for _ in range(len(untrustworthy_reviews_for_testing  ))]

    train_labels = np.concatenate((np.array(train_labels1), np.array(train_labels0)), axis=0)
    test_labels  = np.concatenate((np.array(test_labels1),  np.array(test_labels0)),  axis=0)

    # convert word2idx
    vocabulary, vocabulary_inv = build_vocab(train + test, vocab_size=vocab_size)
    train = build_input_data(train, vocabulary)
    test  = build_input_data(test,   vocabulary)
    
    return train, train_labels, train_labels, train, test_labels, test_labels, vocabulary, vocabulary_inv


def batch_iter(data, batch_size, num_epochs):
    """
    Generates a batch iterator for a dataset.
    """
    data = np.array(data)
    data_size = len(data)
    num_batches_per_epoch = int(len(data)/batch_size) + 1
    for epoch in range(num_epochs):
        # Shuffle the data at each epoch
        shuffle_indices = np.random.permutation(np.arange(data_size))
        shuffled_data = data[shuffle_indices]
        for batch_num in range(num_batches_per_epoch):
            start_index = batch_num * batch_size
            end_index = min((batch_num + 1) * batch_size, data_size)
            yield shuffled_data[start_index:end_index]

# %%
# def get_cross_domain_dataset(test_keys=[]):
#     train_keys = ["hotel"]

#     train_reviews, train_labels = get_data(keys=train_keys, data_name="cross_domain")
#     test_reviews,  test_labels  = get_data(keys=test_keys, data_name="cross_domain")
#     all_reviews = train_reviews + test_reviews
    
#     return train_reviews, train_labels, test_reviews, test_labels

# def get_cross_domain_dataset_restaurant():
#     return get_cross_domain_dataset(test_keys=["restaurant"])

# def get_cross_domain_dataset_doctor():
#     return get_cross_domain_dataset(test_keys=["doctor"])

# %%
def get_mix_domain_dataset(fold=1):
    keys = ["hotel", "restaurant", "doctor"]
    data, labels = get_data(keys=keys, data_name="mixed_domain")

    MAX_FOLD = 5
    LEN_DATA = len(data)
    DELTA = int(LEN_DATA / MAX_FOLD)
    start_idx = (fold-1)*DELTA
    end_idx   = start_idx + DELTA

    # print("HERE", data[0:start_idx])

    train_reviews = data[0:start_idx]
    train_reviews.extend(data[end_idx:])

    train_labels = labels[0:start_idx]
    train_labels.extend(labels[end_idx:])

    test_reviews   = data[start_idx:end_idx]
    test_labels = labels[start_idx:end_idx]

    return train_reviews, train_labels, test_reviews, test_labels

# %% [markdown]
# # Review Dataset

# %%
import torch

class UntrustworthyReviewDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels    = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_data, train_labels, test_data, test_labels = get_mix_domain_dataset(fold=1)

print("mixed_domain_dataset train: ", len(train_data))
print("mixed_domain_dataset test: ", len(test_data))

print(type(train_data))
print(type(test_data))
print(type(train_labels))
print(type(test_labels))
# Out:
# dataset_name: mixed_domain_hotel
# trustworthy_reviews: 1200
# untrustworthy_reviews: 1637
# reviews len:  2837
# labels len:  2837
#
# mixed_domain_dataset train:  2270
# mixed_domain_dataset test:  567
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# # Hyperparameters

# %%
import torch.nn as nn

FOLD = 5
BATCH_SIZE = 16 # 48
LR = 1e-3
EPOCHS = 5
cross_entropy = nn.NLLLoss()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

target_names = ["trustworthy", "untrustworthy"]

# %% [markdown]
# # Define Transformer-based Architecture for Fine-tuning

# %%
class TransformerArchitecture(nn.Module):

    def __init__(self, bert):
      
      super(TransformerArchitecture, self).__init__()

      self.bert = bert 
      
      # dropout layer
      self.dropout = nn.Dropout(0.1)
      
      # relu activation function
      self.relu =  nn.ReLU()

      # dense layer 1
      self.fc1 = nn.Linear(768, 512)
      
      # dense layer 2 (Output layer)
      self.fc2 = nn.Linear(512, 2)

      #softmax activation function
      self.softmax = nn.LogSoftmax(dim=1)

    #define the forward pass
    def forward(self, input_ids, attention_mask):

      #pass the inputs to the model  
      x = self.bert(input_ids, attention_mask=attention_mask)
      # print(x[0])
      
      x = self.fc1(x[0])

      x = self.relu(x)

      x = self.dropout(x)

      # output layer
      x = self.fc2(x)
      
      # apply softmax activation
      x = self.softmax(x)

      return x

# %% [markdown]
# # Define Training Method

# %%
# function to train the model
def train(model, train_dataloader, optimizer):
  
  model.train()

  total_loss, total_accuracy = 0, 0
  
  # empty list to save model predictions
  total_preds, total_labels = [], []
  
  # iterate over batches
  for step, batch in enumerate(train_dataloader):
    
    # progress update after every 50 batches.
    if step % 50 == 0 and not step == 0:
      print('  Batch {:>5,}  of  {:>5,}.'.format(step, len(train_dataloader)))

    # push the batch to gpu
    input_ids      = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    labels         = batch['labels'].to(device)

    # clear previously calculated gradients 
    model.zero_grad()        

    # get model predictions for the current batch
    preds = model(input_ids, attention_mask)

    # compute the loss between actual and predicted values
    loss = cross_entropy(preds, labels)

    # add on to the total loss
    total_loss = total_loss + loss.item()

    # print('train_loss ', loss.item())

    # backward pass to calculate the gradients
    loss.backward()

    # clip the the gradients to 1.0. It helps in preventing the exploding gradient problem
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) # ADDED

    # update parameters
    optimizer.step()

    # model predictions are stored on GPU. So, push it to CPU
    preds = preds.detach().cpu().numpy()
    labels = labels.detach().cpu().numpy()

    # append the model predictions
    total_preds.append(preds)
    total_labels.append(labels)
    
  # compute the training loss of the epoch
  avg_loss = total_loss / len(train_dataloader)
  # print("train loss: ", avg_loss)

  
  # predictions are in the form of (no. of batches, size of batch, no. of cla
  # reshape the predictions in form of (number of samples, no. of classes)
  total_preds   = np.concatenate(total_preds, axis=0)
  total_labels  = np.concatenate(total_labels, axis=0)
  

  #returns the loss and predictions
  return avg_loss, total_preds, total_labels

# %% [markdown]
# # Define Evaluating Method

# %%
def evaluate(model, valid_dataloader):
  
  print("\nEvaluating...")
  
  # deactivate dropout layers
  model.eval()

  total_loss, total_accuracy = 0, 0
  
  # empty list to save the model predictions
  total_preds, total_labels = [], []

  # iterate over batches
  for step, batch in enumerate(valid_dataloader):
    
    # Progress update every 50 batches.
    if step % 50 == 0 and not step == 0:
      
      # Calculate elapsed time in minutes.
      # elapsed = format_time(time.time() - t0)
            
      # Report progress.
      print('  Batch {:>5,}  of  {:>5,}.'.format(step, len(valid_dataloader)))

    # push the batch to gpu
    input_ids      = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    labels         = batch['labels'].to(device)

    # deactivate autograd
    with torch.no_grad():
      
      # model predictions
      preds = model(input_ids, attention_mask)

      # compute the validation loss between actual and predicted values
      loss = cross_entropy(preds, labels)

      total_loss = total_loss + loss.item()
      # print('valid_loss ', loss.item())

      # model predictions are stored on GPU. So, push it to CPU
      preds = preds.detach().cpu().numpy()
      labels = labels.detach().cpu().numpy()

      # append the model predictions
      total_preds.append(preds)
      total_labels.append(labels)

  # compute the validation loss of the epoch
  avg_loss = total_loss / len(valid_dataloader) 
  # print("eval loss: ", avg_loss)

  # reshape the predictions in form of (number of samples, no. of classes)
  total_preds  = np.concatenate(total_preds, axis=0)
  total_labels  = np.concatenate(total_labels, axis=0)

  return avg_loss, total_preds, total_labels

# %% [markdown]
# # Train and Validate

# %%
from sklearn.metrics import classification_report


def train_and_validate(model, model_name, train_dataloader, valid_dataloader, optimizer, fold):
  best_valid_loss = 30

  # set initial loss to infinite
  best_valid_loss = float('inf')
  best_accuracy = 0 

  # empty lists to store training and validation loss of each epoch
  train_losses=[]
  valid_losses=[]
  for epoch in range(EPOCHS):
      print('\n Epoch {:} / {:}'.format(epoch + 1, EPOCHS))
      
      # train model
      train_loss, train_preds, train_labels = train(model, train_dataloader, optimizer)
      
      # evaluate model
      valid_loss, valid_preds, valid_labels = evaluate(model, valid_dataloader)
      
      # append training and validation loss
      train_losses.append(train_loss)
      valid_losses.append(valid_loss)
      
      print(f'\nTraining Loss: {train_loss:.3f}')
      print(f'Validation Loss: {valid_loss:.3f}')
     
      train_labels = np.argmax(train_labels, axis = 1)
      train_preds = np.argmax(np.argmax(train_preds, axis = 1), axis=1) # inner argmax try softmax
      train_report = classification_report(train_labels, train_preds, target_names=target_names, output_dict=True)
      add(train_report, report, stage='train', metrics=metrics, model_name=model_name, fold=fold)

      valid_labels = np.argmax(valid_labels, axis = 1)
      valid_preds = np.argmax(np.argmax(valid_preds, axis = 1), axis=1)
      valid_report = classification_report(valid_labels, valid_preds, target_names=target_names, output_dict=True)
      add(valid_report, report, stage='valid', metrics=metrics, model_name=model_name, fold=fold)

      # print the best results for a given model (and save its weights)
      current_accuracy = 0
      for metric in metrics:
        if metric == "accuracy":
          current_accuracy += valid_report[metric]
        else:
          current_accuracy += valid_report['macro avg'][metric]

      if best_accuracy < current_accuracy:
        best_accuracy = current_accuracy
        print('Best Accuracy for the model {:} at {:} epoch'.format(model_name, epoch + 1))
        print(valid_report)
        # torch.save(model.state_dict(), model_name + '-best.pt')

      # if valid_loss < best_valid_loss:
      #     best_valid_loss = valid_loss
      #     torch.save(model.state_dict(), 'best.pt')

  return report

# %%
def freeze_parameters(transformer_model):
  # freeze all the parameters
  for param in transformer_model.parameters():
      param.requires_grad = False

# %%
from transformers import AutoModel
from transformers import AutoTokenizer
from torch.optim import AdamW


def train_and_evaluate(model_name, fold):
  transformer_model = AutoModel.from_pretrained(model_name)
  freeze_parameters(transformer_model)

  # Extend the model for fine-tuning
  model_architecture = TransformerArchitecture(transformer_model)
  model_architecture.to(device)

  optimizer = AdamW(model_architecture.parameters(), lr = LR)

  tokenizer = AutoTokenizer.from_pretrained(model_name)     

  train_data, train_labels, test_data, test_labels = get_mix_domain_dataset(fold)

  train_encodings  = tokenizer(train_data, truncation=True, padding=True)
  test_encodings   = tokenizer(test_data, truncation=True, padding=True)

  train_dataset    = UntrustworthyReviewDataset(train_encodings, train_labels)
  valid_dataset    = UntrustworthyReviewDataset(test_encodings, test_labels)

  train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
  valid_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

  report = train_and_validate(model_architecture, model_name, train_dataloader, valid_dataloader, optimizer, fold)
  
  return report

# %% [markdown]
# # Plotting Methods

# %%
from matplotlib import pyplot


def initialize_report(stages=['train', 'valid'], metrics=['precision', 'recall', 'f1-score', 'accuracy'], model_names=[]):
  report = {}
  for model_name in model_names:
    report[model_name] = {}
    for stage in stages:
        report[model_name][stage] = {}
        for fold in range(1, FOLD+1):
          report[model_name][stage][fold] = {}
          for metric in metrics:
              report[model_name][stage][fold][metric] = []

  return report


def add(cls_report, report, stage, metrics, model_name, fold):
  metrics = ['precision', 'recall', 'f1-score', 'accuracy']
  for metric in metrics:
    if metric == "accuracy":
      report[model_name][stage][fold][metric].append(cls_report[metric])
    else:
      report[model_name][stage][fold][metric].append(cls_report['weighted avg'][metric])


def plot_results(report, stages, metrics, model_names):
  for stage in stages:
    pyplot.subplot(212)
    for metric in metrics:
      pyplot.title(stage + ' ' + metric)
      for model_name in model_names:
        pyplot.xlabel('epochs')
        pyplot.ylabel(metric) 

        eval_metric = report[model_name][stage][0][metric]
        epochs = [(i+1) for i in range(len(eval_metric))]

        pyplot.plot(epochs, eval_metric, label=model_name, 
                    marker='o', linestyle='--')
        
      pyplot.legend()
      pyplot.show()

# %%
def avg_over_folds(report, stages=['train', 'valid'], metrics=['precision', 'recall', 'f1-score', 'accuracy'], model_names=[]): 
  for model_name in model_names:
    for stage in stages:
      report[model_name][stage][0] = {} 
      for metric in metrics:
        
        avgs = []
        for epoch in range(EPOCHS):
          avg = 0
          for fold in range(1, FOLD+1):
            avg += report[model_name][stage][fold][metric][epoch] 
          avg = avg/float(FOLD)
          avgs.append(avg)

        report[model_name][stage][0][metric] = avgs

# %% [markdown]
# # Print Best Report Method

# %%
# import pandas as pd

# def print_report(report, stages=['train', 'valid'], metrics=['precision', 'recall', 'f1-score', 'accuracy'], model_names=[]):
#   for stage in ['eval']:
#     best_report = None
#     best_result = []
#     for model_name in model_names:
      
#       # identify best report
#       model_best_result = []
#       model_best_accuracy = 0
#       for epoch in EPOCHS:
        
#         current_accuracy = 0
#         for epoch in EPOCHS:
#           if metric == "accuracy":
#               current_accuracy += report[model_name][stage][0][metric][epoch]
#           else:
#               current_accuracy += report[model_name][stage][0][metric]['weighted avg'][metric][epoch]

#         if model_best_accuracy < current_accuracy:
#           current_accuracy = model_best_accuracy
#           model_best_epoch = epoch
#           model_best_result = []
#           for metric in metrics:
#             model_best_result.append(report[model_name][stage][0][metric][epoch])  
       
#        best_result.append([model_name].append(model_best_result))     


#     print( pd.DataFrame(best_result, columns=['model_name'].append(metrics)) )
#     print()

# %% [markdown]
# # Run the Experiment

# %%
stages = ['train', 'valid']
metrics = ['precision', 'recall', 'f1-score', 'accuracy']
model_names = ['bert-base-uncased', 'roberta-base', 'microsoft/deberta-base', 'funnel-transformer/medium-base']
model_names = ['roberta-base']


report = initialize_report(stages=['train', 'valid'], metrics=['precision', 'recall', 'f1-score', 'accuracy'], model_names=model_names)
print(report)


for model_name in model_names:
  for fold in range(1, FOLD+1):
    train_and_evaluate(model_name, fold)
# Out:
# {'roberta-base': {'train': {1: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 2: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 3: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 4: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 5: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}}, 'valid': {1: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 2: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 3: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 4: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}, 5: {'precision': [], 'recall': [], 'f1-score': [], 'accuracy': []}}}}
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# dataset_name: mixed_domain_hotel
# trustworthy_reviews: 1200
# untrustworthy_reviews: 1637
# reviews len:  2837
# labels len:  2837
#
#
#  Epoch 1 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 2.453
# Validation Loss: 0.920
# Best Accuracy for the model roberta-base at 1 epoch
# {'trustworthy': {'precision': 0.445600756859035, 'recall': 0.7440758293838863, 'f1-score': 0.5573964497041419, 'support': 633}, 'untrustworthy': {'precision': 0.8664468260511129, 'recall': 0.6420281001832621, 'f1-score': 0.7375438596491227, 'support': 1637}, 'accuracy': 0.6704845814977973, 'macro avg': {'precision': 0.656023791455074, 'recall': 0.6930519647835742, 'f1-score': 0.6474701546766324, 'support': 2270}, 'weighted avg': {'precision': 0.7490919530120885, 'recall': 0.6704845814977973, 'f1-score': 0.6873089211049938, 'support': 2270}}
#
#  Epoch 2 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.764
# Validation Loss: 0.720
# Best Accuracy for the model roberta-base at 2 epoch
# {'trustworthy': {'precision': 0.65149359886202, 'recall': 0.7235387045813586, 'f1-score': 0.6856287425149701, 'support': 633}, 'untrustworthy': {'precision': 0.8883216336949585, 'recall': 0.8503359804520464, 'f1-score': 0.8689138576779025, 'support': 1637}, 'accuracy': 0.8149779735682819, 'macro avg': {'precision': 0.7699076162784892, 'recall': 0.7869373425167026, 'f1-score': 0.7772713000964363, 'support': 2270}, 'weighted avg': {'precision': 0.8222810407217206, 'recall': 0.8149779735682819, 'f1-score': 0.8178039555201332, 'support': 2270}}
#
#  Epoch 3 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.602
# Validation Loss: 0.620
#
#  Epoch 4 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.469
# Validation Loss: 0.526
# Best Accuracy for the model roberta-base at 4 epoch
# {'trustworthy': {'precision': 0.7697841726618705, 'recall': 0.6761453396524486, 'f1-score': 0.7199327165685451, 'support': 633}, 'untrustworthy': {'precision': 0.8803967327887982, 'recall': 0.921808185705559, 'f1-score': 0.9006266786034021, 'support': 1637}, 'accuracy': 0.8533039647577092, 'macro avg': {'precision': 0.8250904527253343, 'recall': 0.7989767626790039, 'f1-score': 0.8102796975859736, 'support': 2270}, 'weighted avg': {'precision': 0.8495519087534037, 'recall': 0.8533039647577092, 'f1-score': 0.8502393314809067, 'support': 2270}}
#
#  Epoch 5 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.381
# Validation Loss: 0.566
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# dataset_name: mixed_domain_hotel
# trustworthy_reviews: 1200
# untrustworthy_reviews: 1637
# reviews len:  2837
# labels len:  2837
#
#
#  Epoch 1 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 2.434
# Validation Loss: 0.904
# Best Accuracy for the model roberta-base at 1 epoch
# {'trustworthy': {'precision': 0.5149082568807339, 'recall': 0.7093206951026856, 'f1-score': 0.5966777408637874, 'support': 633}, 'untrustworthy': {'precision': 0.8683834048640916, 'recall': 0.7416004886988393, 'f1-score': 0.8, 'support': 1637}, 'accuracy': 0.7325991189427313, 'macro avg': {'precision': 0.6916458308724127, 'recall': 0.7254605919007624, 'f1-score': 0.6983388704318938, 'support': 2270}, 'weighted avg': {'precision': 0.7698152248317279, 'recall': 0.7325991189427313, 'f1-score': 0.743302647562457, 'support': 2270}}
#
#  Epoch 2 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.732
# Validation Loss: 0.742
# Best Accuracy for the model roberta-base at 2 epoch
# {'trustworthy': {'precision': 0.5476718403547672, 'recall': 0.7804107424960506, 'f1-score': 0.6436482084690555, 'support': 633}, 'untrustworthy': {'precision': 0.8983918128654971, 'recall': 0.7507635919364691, 'f1-score': 0.8179700499168054, 'support': 1637}, 'accuracy': 0.7590308370044053, 'macro avg': {'precision': 0.7230318266101321, 'recall': 0.7655871672162599, 'f1-score': 0.7308091291929304, 'support': 2270}, 'weighted avg': {'precision': 0.8005919262578794, 'recall': 0.7590308370044053, 'f1-score': 0.7693595980945915, 'support': 2270}}
#
#  Epoch 3 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.570
# Validation Loss: 0.622
#
#  Epoch 4 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.436
# Validation Loss: 0.500
# Best Accuracy for the model roberta-base at 4 epoch
# {'trustworthy': {'precision': 0.7032163742690059, 'recall': 0.7598736176935229, 'f1-score': 0.730447987851177, 'support': 633}, 'untrustworthy': {'precision': 0.9041614123581336, 'recall': 0.87599266951741, 'f1-score': 0.8898541731306236, 'support': 1637}, 'accuracy': 0.8436123348017621, 'macro avg': {'precision': 0.8036888933135697, 'recall': 0.8179331436054664, 'f1-score': 0.8101510804909003, 'support': 2270}, 'weighted avg': {'precision': 0.8481269590055267, 'recall': 0.8436123348017621, 'f1-score': 0.8454030210240643, 'support': 2270}}
#
#  Epoch 5 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.355
# Validation Loss: 0.587
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# dataset_name: mixed_domain_hotel
# trustworthy_reviews: 1200
# untrustworthy_reviews: 1637
# reviews len:  2837
# labels len:  2837
#
#
#  Epoch 1 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 2.553
# Validation Loss: 0.979
# Best Accuracy for the model roberta-base at 1 epoch
# {'trustworthy': {'precision': 0.5939675174013921, 'recall': 0.9029982363315696, 'f1-score': 0.7165850244926522, 'support': 1134}, 'untrustworthy': {'precision': 0.7985347985347986, 'recall': 0.38380281690140844, 'f1-score': 0.5184304399524375, 'support': 1136}, 'accuracy': 0.6431718061674009, 'macro avg': {'precision': 0.6962511579680953, 'recall': 0.643400526616489, 'f1-score': 0.6175077322225448, 'support': 2270}, 'weighted avg': {'precision': 0.696341275713088, 'recall': 0.6431718061674009, 'f1-score': 0.6174204394540249, 'support': 2270}}
#
#  Epoch 2 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.818
# Validation Loss: 0.744
# Best Accuracy for the model roberta-base at 2 epoch
# {'trustworthy': {'precision': 0.6763732627399074, 'recall': 0.9012345679012346, 'f1-score': 0.7727788279773156, 'support': 1134}, 'untrustworthy': {'precision': 0.852437417654809, 'recall': 0.5695422535211268, 'f1-score': 0.6828496042216359, 'support': 1136}, 'accuracy': 0.7352422907488987, 'macro avg': {'precision': 0.7644053401973582, 'recall': 0.7353884107111807, 'f1-score': 0.7278142160994757, 'support': 2270}, 'weighted avg': {'precision': 0.7644829014990828, 'recall': 0.7352422907488987, 'f1-score': 0.7277745997013455, 'support': 2270}}
#
#  Epoch 3 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.649
# Validation Loss: 0.756
# Best Accuracy for the model roberta-base at 3 epoch
# {'trustworthy': {'precision': 0.6873760740251157, 'recall': 0.9171075837742504, 'f1-score': 0.7857952398942198, 'support': 1134}, 'untrustworthy': {'precision': 0.8758256274768824, 'recall': 0.5836267605633803, 'f1-score': 0.7004754358161648, 'support': 1136}, 'accuracy': 0.7502202643171806, 'macro avg': {'precision': 0.781600850750999, 'recall': 0.7503671721688153, 'f1-score': 0.7431353378551924, 'support': 2270}, 'weighted avg': {'precision': 0.7816838681754271, 'recall': 0.7502202643171806, 'f1-score': 0.7430977520384179, 'support': 2270}}
#
#  Epoch 4 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.530
# Validation Loss: 0.600
# Best Accuracy for the model roberta-base at 4 epoch
# {'trustworthy': {'precision': 0.7402877697841727, 'recall': 0.9074074074074074, 'f1-score': 0.8153724247226624, 'support': 1134}, 'untrustworthy': {'precision': 0.8806818181818182, 'recall': 0.6822183098591549, 'f1-score': 0.7688492063492063, 'support': 1136}, 'accuracy': 0.7947136563876652, 'macro avg': {'precision': 0.8104847939829954, 'recall': 0.7948128586332812, 'f1-score': 0.7921108155359343, 'support': 2270}, 'weighted avg': {'precision': 0.8105466415814084, 'recall': 0.7947136563876652, 'f1-score': 0.7920903207260781, 'support': 2270}}
#
#  Epoch 5 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.447
# Validation Loss: 0.537
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# dataset_name: mixed_domain_hotel
# trustworthy_reviews: 1200
# untrustworthy_reviews: 1637
# reviews len:  2837
# labels len:  2837
#
#
#  Epoch 1 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 2.529
# Validation Loss: 0.878
# Best Accuracy for the model roberta-base at 1 epoch
# {'trustworthy': {'precision': 0.592516658124039, 'recall': 0.9633333333333334, 'f1-score': 0.733735322119962, 'support': 1200}, 'untrustworthy': {'precision': 0.8620689655172413, 'recall': 0.2570093457943925, 'f1-score': 0.3959683225341972, 'support': 1070}, 'accuracy': 0.6303964757709251, 'macro avg': {'precision': 0.7272928118206401, 'recall': 0.6101713395638629, 'f1-score': 0.5648518223270795, 'support': 2270}, 'weighted avg': {'precision': 0.7195743536794251, 'recall': 0.6303964757709251, 'f1-score': 0.5745235646059672, 'support': 2270}}
#
#  Epoch 2 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.762
# Validation Loss: 0.850
# Best Accuracy for the model roberta-base at 2 epoch
# {'trustworthy': {'precision': 0.7178314826910516, 'recall': 0.9158333333333334, 'f1-score': 0.80483339436104, 'support': 1200}, 'untrustworthy': {'precision': 0.8633288227334236, 'recall': 0.5962616822429907, 'f1-score': 0.7053620784964069, 'support': 1070}, 'accuracy': 0.7651982378854626, 'macro avg': {'precision': 0.7905801527122376, 'recall': 0.7560475077881621, 'f1-score': 0.7550977364287235, 'support': 2270}, 'weighted avg': {'precision': 0.7864139293189538, 'recall': 0.7651982378854626, 'f1-score': 0.757946034019561, 'support': 2270}}
#
#  Epoch 3 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.560
# Validation Loss: 0.518
# Best Accuracy for the model roberta-base at 3 epoch
# {'trustworthy': {'precision': 0.7830121341898644, 'recall': 0.9141666666666667, 'f1-score': 0.8435217224144561, 'support': 1200}, 'untrustworthy': {'precision': 0.8814729574223246, 'recall': 0.7158878504672898, 'f1-score': 0.7900979886539452, 'support': 1070}, 'accuracy': 0.8207048458149779, 'macro avg': {'precision': 0.8322425458060945, 'recall': 0.8150272585669782, 'f1-score': 0.8168098555342007, 'support': 2270}, 'weighted avg': {'precision': 0.8294231830263104, 'recall': 0.8207048458149779, 'f1-score': 0.8183396100251404, 'support': 2270}}
#
#  Epoch 4 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.423
# Validation Loss: 0.537
# Best Accuracy for the model roberta-base at 4 epoch
# {'trustworthy': {'precision': 0.7854107648725213, 'recall': 0.9241666666666667, 'f1-score': 0.8491577335375192, 'support': 1200}, 'untrustworthy': {'precision': 0.8939393939393939, 'recall': 0.7168224299065421, 'f1-score': 0.795643153526971, 'support': 1070}, 'accuracy': 0.826431718061674, 'macro avg': {'precision': 0.8396750794059575, 'recall': 0.8204945482866044, 'f1-score': 0.8224004435322452, 'support': 2270}, 'weighted avg': {'precision': 0.8365674314370825, 'recall': 0.826431718061674, 'f1-score': 0.8239327993475251, 'support': 2270}}
#
#  Epoch 5 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.352
# Validation Loss: 0.490
# Best Accuracy for the model roberta-base at 5 epoch
# {'trustworthy': {'precision': 0.8726169844020797, 'recall': 0.8391666666666666, 'f1-score': 0.8555649957519117, 'support': 1200}, 'untrustworthy': {'precision': 0.8270609318996416, 'recall': 0.8626168224299066, 'f1-score': 0.8444647758462945, 'support': 1070}, 'accuracy': 0.8502202643171806, 'macro avg': {'precision': 0.8498389581508606, 'recall': 0.8508917445482866, 'f1-score': 0.8500148857991031, 'support': 2270}, 'weighted avg': {'precision': 0.8511434266145868, 'recall': 0.8502202643171806, 'f1-score': 0.8503327335056517, 'support': 2270}}
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# dataset_name: mixed_domain_hotel
# trustworthy_reviews: 1200
# untrustworthy_reviews: 1637
# reviews len:  2837
# labels len:  2837
#
#
#  Epoch 1 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 2.547
# Validation Loss: 1.080
# Best Accuracy for the model roberta-base at 1 epoch
# {'trustworthy': {'precision': 0.5317815577439571, 'recall': 0.99, 'f1-score': 0.6919044845661037, 'support': 1200}, 'untrustworthy': {'precision': 0.6666666666666666, 'recall': 0.022429906542056073, 'f1-score': 0.04339963833634719, 'support': 1070}, 'accuracy': 0.533920704845815, 'macro avg': {'precision': 0.5992241122053119, 'recall': 0.5062149532710281, 'f1-score': 0.3676520614512254, 'support': 2270}, 'weighted avg': {'precision': 0.5953617632714017, 'recall': 0.533920704845815, 'f1-score': 0.3862215834798308, 'support': 2270}}
#
#  Epoch 2 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.828
# Validation Loss: 0.737
# Best Accuracy for the model roberta-base at 2 epoch
# {'trustworthy': {'precision': 0.646188850967008, 'recall': 0.9466666666666667, 'f1-score': 0.7680865449628126, 'support': 1200}, 'untrustworthy': {'precision': 0.875, 'recall': 0.41869158878504675, 'f1-score': 0.5663716814159292, 'support': 1070}, 'accuracy': 0.6977973568281939, 'macro avg': {'precision': 0.760594425483504, 'recall': 0.6826791277258567, 'f1-score': 0.6672291131893708, 'support': 2270}, 'weighted avg': {'precision': 0.7540425643878456, 'recall': 0.6977973568281939, 'f1-score': 0.6730050894583345, 'support': 2270}}
#
#  Epoch 3 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.655
# Validation Loss: 0.614
# Best Accuracy for the model roberta-base at 3 epoch
# {'trustworthy': {'precision': 0.6911220715166461, 'recall': 0.9341666666666667, 'f1-score': 0.7944720056697377, 'support': 1200}, 'untrustworthy': {'precision': 0.8780864197530864, 'recall': 0.5317757009345795, 'f1-score': 0.6623981373690337, 'support': 1070}, 'accuracy': 0.7444933920704846, 'macro avg': {'precision': 0.7846042456348663, 'recall': 0.7329711838006231, 'f1-score': 0.7284350715193857, 'support': 2270}, 'weighted avg': {'precision': 0.7792506409496819, 'recall': 0.7444933920704846, 'f1-score': 0.7322169223738111, 'support': 2270}}
#
#  Epoch 4 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.502
# Validation Loss: 0.697
# Best Accuracy for the model roberta-base at 4 epoch
# {'trustworthy': {'precision': 0.6991315136476427, 'recall': 0.9391666666666667, 'f1-score': 0.8015647226173542, 'support': 1200}, 'untrustworthy': {'precision': 0.8890577507598785, 'recall': 0.5467289719626168, 'f1-score': 0.6770833333333333, 'support': 1070}, 'accuracy': 0.7541850220264317, 'macro avg': {'precision': 0.7940946322037605, 'recall': 0.7429478193146417, 'f1-score': 0.7393240279753437, 'support': 2270}, 'weighted avg': {'precision': 0.7886562157225732, 'recall': 0.7541850220264317, 'f1-score': 0.7428884730429479, 'support': 2270}}
#
#  Epoch 5 / 5
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Evaluating...
#   Batch    50  of    142.
#   Batch   100  of    142.
#
# Training Loss: 1.449
# Validation Loss: 0.541
# Best Accuracy for the model roberta-base at 5 epoch
# {'trustworthy': {'precision': 0.7062461348175634, 'recall': 0.9516666666666667, 'f1-score': 0.8107916222932197, 'support': 1200}, 'untrustworthy': {'precision': 0.9111791730474732, 'recall': 0.5560747663551402, 'f1-score': 0.6906558328496808, 'support': 1070}, 'accuracy': 0.7651982378854626, 'macro avg': {'precision': 0.8087126539325182, 'recall': 0.7538707165109034, 'f1-score': 0.7507237275714502, 'support': 2270}, 'weighted avg': {'precision': 0.8028445272871685, 'recall': 0.7651982378854626, 'f1-score': 0.7541637391634458, 'support': 2270}}

# %% [markdown]
# # Plot Results

# %%
report
# Out:
# {'roberta-base': {'train': {1: {'accuracy': [0.38061674008810575,
#      0.4502202643171806,
#      0.4933920704845815,
#      0.5035242290748899,
#      0.5343612334801762],
#     'f1-score': [0.347227712566632,
#      0.44388309525270847,
#      0.5014922042666408,
#      0.5155741211021854,
#      0.5518409624852035],
#     'precision': [0.6457349771970933,
#      0.6924412987717509,
#      0.6962794375460138,
#      0.6902008580375777,
#      0.6927326459108591],
#     'recall': [0.38061674008810575,
#      0.4502202643171806,
#      0.4933920704845815,
#      0.5035242290748899,
#      0.5343612334801762]},
#    2: {'accuracy': [0.36475770925110135,
#      0.4374449339207048,
#      0.47444933920704846,
#      0.5044052863436124,
#      0.5436123348017621],
#     'f1-score': [0.32253191819504445,
#      0.4355499202505601,
#      0.48474363271447407,
#      0.5193234535052578,
#      0.561241223274764],
#     'precision': [0.632311849773744,
#      0.6564370006142455,
#      0.6633704499778996,
#      0.6772158132553219,
#      0.700066157087285],
#     'recall': [0.36475770925110135,
#      0.4374449339207048,
#      0.47444933920704846,
#      0.5044052863436124,
#      0.5436123348017621]},
#    3: {'accuracy': [0.47048458149779737,
#      0.479295154185022,
#      0.5101321585903084,
#      0.5259911894273128,
#      0.5277533039647577],
#     'f1-score': [0.3810562329968376,
#      0.4233760890099717,
#      0.474262644307133,
#      0.49539794936305354,
#      0.5045793026864284],
#     'precision': [0.43078377678014895,
#      0.4665982496600719,
#      0.514259930181901,
#      0.5346166915450056,
#      0.5343908066820291],
#     'recall': [0.47048458149779737,
#      0.479295154185022,
#      0.5101321585903084,
#      0.5259911894273128,
#      0.5277533039647577]},
#    4: {'accuracy': [0.4933920704845815,
#      0.4995594713656388,
#      0.49823788546255504,
#      0.5427312775330396,
#      0.5541850220264317],
#     'f1-score': [0.42174652242247435,
#      0.45733130048873194,
#      0.47001223374262185,
#      0.5258140781858037,
#      0.5424734688855383],
#     'precision': [0.45172421460118695,
#      0.4787156522249393,
#      0.48310314282473055,
#      0.5380560120420367,
#      0.5508826047037626],
#     'recall': [0.4933920704845815,
#      0.4995594713656388,
#      0.49823788546255504,
#      0.5427312775330396,
#      0.5541850220264317]},
#    5: {'accuracy': [0.5110132158590308,
#      0.5,
#      0.5220264317180616,
#      0.5343612334801762,
#      0.5273127753303964],
#     'f1-score': [0.41942795086082624,
#      0.44784467115697607,
#      0.4853971969359658,
#      0.5085974064333659,
#      0.5064590713825936],
#     'precision': [0.4727742144796455,
#      0.4746556176689739,
#      0.5108215777523816,
